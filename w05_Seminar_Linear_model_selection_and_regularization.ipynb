# %% [markdown]
# # Week 5 Seminar.
#
# ## Chapter 5. Linear model selection & regularization. ISLR textbook.
#
# ### Course: ML with Python, 2025/2026, HSE
# ### Author: Maria Tikhonova, Oleg Melnikov, teaching team.
#
# ##### Reviewed by: Vsevolod Ovchinnikov, Aleksander Khizik, Saraa Ali

# %% [markdown]
# In this seminar we'll work with the new dataset about microchips (finally, not Titanic!) and practice regularization technics which help to improve the regression quality.
#
# **Keywords:** regularization, L2-regularization, L1-regularization, regression, lasso regression, ridge regression.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns, numpy as np, pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import \
  cross_val_score, StratifiedKFold, GridSearchCV, TimeSeriesSplit, KFold, ShuffleSplit,\
  StratifiedKFold, GroupShuffleSplit, GroupKFold, StratifiedShuffleSplit
from matplotlib.patches import Patch
sns.set()

# %% [markdown]
# ## Prerequisites: dataset loading & EDA
#
# Let's load the data using `read_csv` from the `pandas` library.
#
# This dataset contains information about 118 microchips (objects), their results for two tests of quality control (two numerical variables) and information whether the microchip went into production (target variable).
#
# **Our goal:** to predict whether the chip went into production or not, based on two quality control tests.

# %%
# loading data
data = pd.read_csv('https://raw.githubusercontent.com/omelnikov/data/main/microchip/microchip.txt')
data.columns = ['test1','test2','released']
data.head()
# Out:
#       test1    test2  released
# 0  0.051267  0.69956         1
# 1 -0.092742  0.68494         1
# 2 -0.213710  0.69225         1
# 3 -0.375000  0.50219         1
# 4 -0.513250  0.46564         1

# %% [markdown]
# **Let's perform standard EDA**
#
# **Takeaway:** Luckily there are no missing values and all the atrributes are numerical. Moreover, average for both tests is close to zero, they lie in the same range and there are no outliers.

# %%
# getting some info about dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   test1     118 non-null    float64
#  1   test2     118 non-null    float64
#  2   released  118 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.9 KB

# %%
# method .round(2) make a rounding of output floats
data.describe().T.round(2)
# Out:
#           count  mean   std   min   25%   50%   75%   max
# test1     118.0  0.05  0.50 -0.83 -0.37 -0.01  0.48  1.07
# test2     118.0  0.18  0.52 -0.77 -0.25  0.21  0.65  1.11
# released  118.0  0.49  0.50  0.00  0.00  0.00  1.00  1.00

# %%
data['released']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 113    0
# 114    0
# 115    0
# 116    0
# 117    0
# Name: released, Length: 118, dtype: int64

# %%
data.released.value_counts()
# Out:
# released
# 0    60
# 1    58
# Name: count, dtype: int64

# %%
plt.figure()
sns.boxplot(data=data[['test1','test2']], orient='h')
plt.title('Distribution of features scores')
plt.xlabel('features')
plt.show()

# %% [markdown]
# Let's look at the head of the DataFrame.

# %%
data.head(5).T.round(2)
# Out:
#              0     1     2     3     4
# test1     0.05 -0.09 -0.21 -0.38 -0.51
# test2     0.70  0.68  0.69  0.50  0.47
# released  1.00  1.00  1.00  1.00  1.00

# %%
data[data.test2 > 0].released.value_counts()
# Out:
# released
# 1    37
# 0    33
# Name: count, dtype: int64

# %% [markdown]
# # Visualizing the data
#
# For convenience we will store features and the target class labels in separate NumPy arrays.

# %%
X = data.iloc[:,:2].values
y = data.iloc[:,2].values

# %% [markdown]
# **Why:** visualizing the data could give us some insights about class distributions.
#
# **Takeaway:** we see that classes are NOT lineary separable. Realeased microchips (blue class) basically lie inside the Faulty (orange class) ones.
#
# **Question:** will simple linear regression perform well on such dataset as it is? What could we do to make it work?

# %%
plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title('2 tests of microchips. Logit with C=1')
plt.legend();

# %% [markdown]
# ### Question Time
# Looking at the scatter plot, do you think a simple linear boundary will be enough to separate the two classes?
#
# If not, what could be a strategy to make the data more separable?
#
# `Answer is in the hidden cell below`

# %%
# @title

# A simple linear boundary will likely perform poorly because the classes overlap in a nonlinear way.
# One strategy is to **transform the input features** (for ex. polynomial features) so that a linear model
#  can separate them in the transformed space.

# %% [markdown]
# Technical function to display the separating curve of the classifier.

# %%
def plot_boundary(clf, X, y, grid_step=.01, poly_featurizer=None):
    x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
    y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, grid_step),
                         np.arange(y_min, y_max, grid_step))

    # to every point from [x_min, m_max]x[y_min, y_max]
    # we put in correspondence its own color
    # If a featurizer is provided, transform; otherwise pass raw grid
    grid = np.c_[xx.ravel(), yy.ravel()]

    # If a featurizer is provided, transform; otherwise pass raw grid.
    if poly_featurizer is not None:
        Z = clf.predict(poly_featurizer.transform(np.c_[xx.ravel(), yy.ravel()]))
    else:
        grid_in = grid
        Z = clf.predict(grid_in)

    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z, cmap=plt.cm.Paired)

# %% [markdown]
# # Polynomial features
#
# **Why:** one solution is to transform the dataset and to define polynomial features. Then applying linear regression to the transormed dataset will reasult in the non-linear bound in the original feature space.
#
# **Recap:** We define the following polynomial features of degree $d$ for two variables $x_1$ and $x_2$:
#
# $$\large \{x_1^d, x_1^{d-1}x_2, \ldots x_2^d\} =  \{x_1^ix_2^j\}_{i+j\leq d, i,j \in \mathbb{N}}$$
#
# For example, for $d=3$, this will be the following features:
#
# $$\large 1, x_1, x_2,  x_1^2, x_1x_2, x_2^2, x_1^3, x_1^2x_2, x_1x_2^2, x_2^3$$
#
#
# **Attention:** The number of such features is exponentially large, and it can be costly to build polynomial features of large degree (e.g $d=10$) for 100 variables. More importantly, it's not needed.

# %% [markdown]
# We will use `sklearn`'s implementation of polynimial transformation `PolynomialFeatures`. So, we create an object that will add polynomial features up to degree 7 to matrix $X$.

# %%
poly = PolynomialFeatures(degree=7)
X_poly = poly.fit_transform(X)

# %%
X[:10]
# Out:
# array([[ 0.051267,  0.69956 ],
#        [-0.092742,  0.68494 ],
#        [-0.21371 ,  0.69225 ],
#        [-0.375   ,  0.50219 ],
#        [-0.51325 ,  0.46564 ],
#        [-0.52477 ,  0.2098  ],
#        [-0.39804 ,  0.034357],
#        [-0.30588 , -0.19225 ],
#        [ 0.016705, -0.40424 ],
#        [ 0.13191 , -0.51389 ]])

# %%
X_poly.shape
# Out:
# (118, 36)

# %% [markdown]
# # Ridge regression
#
# Ridge regression is very similar to least squares, except that the coefficients in ridge are estimated by minimizing a slightly different function:
#
# $$\Large J(X, y, \beta) = \mathcal{L} + \lambda \sum_j\beta_j^2$$
#
#
# - $\mathcal{L}$ is the least ordinary squares loss function summed over the entire dataset
# - $\lambda \sum_j\beta_j^2$ is called $l_2$ penalty
#
#
# where $\lambda ≥ 0$ is a tuning parameter, to be determined separately. As with least squares, ridge regression seeks coefficient estimates that fit the data well, by making the RSS small. However, the second term, $\lambda |\beta|^2$ , called a *shrinkage penalty*, is small when betas are close to zero, and so it has the effect of shrinking penalty the estimates of $\beta_j$ towards zero. The tuning parameter $\lambda$ serves to control
# the relative impact of these two terms on the regression coefficient estimates. When $\lambda = 0$, the penalty term has no effect, and ridge regression will produce the least squares estimates. However, as $\lambda$ increases the impact of the shrinkage penalty grows, and the ridge regression coefficient estimates will approach zero.

# %% [markdown]
# $\hat{\beta}_{\text{OLS}} = (X^TX)^{-1}X^Ty;\ \hat{y} = X\hat{\beta_{\text{OLS}}}$
#
# $\hat{\beta}_{\text{Ridge}} = (X^TX + \lambda I)^{-1}X^Ty;\ \hat{y} = X\hat{\beta_{\text{Ridge}}}$

# %% [markdown]
# In the case of logistic regression, a reverse regularization coefficient
#
# $C=\frac{1}{\lambda}$ is typically introduced.
#
# # First experiments with ridge regression
# **Why:** let's build several ridge regressions with different $C = [1e-2, 0.5, 1,100, 1000, 10000]$ to get the idea, how the parameter influences the model and then we discuss the results and the mathematical explanation for them.

# %%
#X_poly[:, 1:] = (X_poly[:, 1:] - X_poly[:, 1:].mean(axis=0, keepdims=True)) / X_poly[:, 1:].std(axis=0, keepdims=True)

# %%
Cs = [1e-2, 0.5, 1, 100, 1000, 10000]

for C in Cs:
    logit = LogisticRegression(C=C, penalty = 'l2', random_state=17, max_iter = 1000)
    logit.fit(X_poly, y)
    print('C = ', C)
    print("Accuracy on training set:",
          round(logit.score(X_poly, y), 3))
    plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=poly)

    plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
    plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
    plt.xlabel("Test 1")
    plt.ylabel("Test 2")
    plt.title('2 tests of microchips. Logit with C=%s' % C)
    plt.legend()
    plt.show()
    print('\n\n\n')
# Out:
# C =  0.01
# Accuracy on training set: 0.627
# C =  0.5
# Accuracy on training set: 0.831
# C =  1
# Accuracy on training set: 0.831
# C =  100
# Accuracy on training set: 0.839
# C =  1000
# Accuracy on training set: 0.873
# C =  10000
# Accuracy on training set: 0.873

# %% [markdown]
# To discuss the results, let's rewrite the function that is optimized in logistic regression with the form:
#
# $$\large J(X,y,w) = \mathcal{L} + \frac{1}{C}||w||^2,$$
#
# where
#
# - $\mathcal{L}$ is the logistic loss function summed over the entire dataset
# - $C$ is the reverse regularization coefficient

# %% [markdown]
# **Takeaway**:
# - the larger the parameter $C$, the more complex the relationships in the data that the model can recover (intuitively $C$ corresponds to the "complexity" of the model - model capacity)
# - if regularization is too strong i.e. the values of $C$ are small, the solution to the problem of minimizing the logistic loss function may be the one where many of the weights are too small or zeroed. The model is also not sufficiently "penalized" for errors (i.e. in the function $J$, the sum of the squares of the weights "outweighs", and the error $\mathcal{L}$ can be relatively large). In this case, the model will underfit as we saw in our first case.
# - on the contrary, if regularization is too weak i.e. the values of $C$ are large, a vector $w$ with high absolute value components can become the solution to the optimization problem. In this case, $\mathcal{L}$ has a greater contribution to the optimized functional $J$. Loosely speaking, the model is too "afraid" to be mistaken on the objects from the training set and will therefore overfit as we saw in the third case.
# - logistic regression will not "understand" (or "learn") what value of $C$ to choose as it does with the weights $w$. That is to say, it can not be determined by solving the optimization problem in logistic regression. Therefore, $C$ is the a model hyperparameter that is tuned on cross-validation.

# %% [markdown]
# # Regularization parameter tuning
#
# In order to find best value for parameter $C$ we will use cross-validation.
#
# **Brief recap of cross-validation from the previous seminar**

# %%
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=cmap_data)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['class', 'group']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, 100])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax


np.random.seed(0)
cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm
n_splits = 4

def draw_bars(bars, y=0.5, vmin=-.2, vmax=1.2, label=None):
    ax = plt.gca()
    ax.scatter(range(len(bars)),  [y] * len(bars), c=bars, marker='_',
               lw=50, label=label, cmap=cmap_cv, vmin=vmin, vmax=vmax)

def plot_cv_splits(cv, index, title, y=None, groups=None):
    plt.figure()

    y_ticks_pos = []
    y_ticks = []
    for i, (train_idx, test_idx) in enumerate(cv.split(index, y=y, groups=groups)):
        idx_labels = np.array([(idx in train_idx) for idx in index])
        draw_bars(idx_labels, y=0.5+i)
        y_ticks_pos.append(0.5+i)
        y_ticks.append(f'Fold {i}')

    if y is not None:
        i += 1
        draw_bars(y, y=0.5+i, vmin=0.5, vmax=0.8)
        y_ticks_pos.append(0.5+i)
        y_ticks.append(f'Class')

    plt.xlabel('Observation index')
    plt.yticks(y_ticks_pos, y_ticks)
    plt.legend([Patch(color=cmap_cv(.8)), Patch(color=cmap_cv(.02))],
                ['Training set', 'Testing set'], loc=(1.02, .8))

    plt.ylim([0, i+1])
    plt.title(title)
    plt.show()

# %%
cv = KFold(4, shuffle=False)
plot_cv_splits(cv, np.arange(1000), 'How K-Fold distributes observations')

# %% [markdown]
# # Grid search for parameter C
#
# **Why:** Using this example, let's identify the optimal value of the regularization parameter $C$. This can be done using `LogisticRegressionCV` - a grid search of parameters followed by cross-validation. This class is designed specifically for logistic regression (effective algorithms with well-known search parameters). For an arbitrary model, use `GridSearchCV`, `RandomizedSearchCV`, or special algorithms for hyperparameter optimization such as the one implemented in `hyperopt`.

# %%
np.logspace(-10, 10)
# Out:
# array([1.00000000e-10, 2.55954792e-10, 6.55128557e-10, 1.67683294e-09,
#        4.29193426e-09, 1.09854114e-08, 2.81176870e-08, 7.19685673e-08,
#        1.84206997e-07, 4.71486636e-07, 1.20679264e-06, 3.08884360e-06,
#        7.90604321e-06, 2.02358965e-05, 5.17947468e-05, 1.32571137e-04,
#        3.39322177e-04, 8.68511374e-04, 2.22299648e-03, 5.68986603e-03,
#        1.45634848e-02, 3.72759372e-02, 9.54095476e-02, 2.44205309e-01,
#        6.25055193e-01, 1.59985872e+00, 4.09491506e+00, 1.04811313e+01,
#        2.68269580e+01, 6.86648845e+01, 1.75751062e+02, 4.49843267e+02,
#        1.15139540e+03, 2.94705170e+03, 7.54312006e+03, 1.93069773e+04,
#        4.94171336e+04, 1.26485522e+05, 3.23745754e+05, 8.28642773e+05,
#        2.12095089e+06, 5.42867544e+06, 1.38949549e+07, 3.55648031e+07,
#        9.10298178e+07, 2.32995181e+08, 5.96362332e+08, 1.52641797e+09,
#        3.90693994e+09, 1.00000000e+10])

# %%
np.logspace(-2, 3, 500)
# Out:
# array([1.00000000e-02, 1.02334021e-02, 1.04722519e-02, 1.07166765e-02,
#        1.09668060e-02, 1.12227736e-02, 1.14847155e-02, 1.17527712e-02,
#        1.20270833e-02, 1.23077980e-02, 1.25950646e-02, 1.28890361e-02,
#        1.31898690e-02, 1.34977233e-02, 1.38127630e-02, 1.41351558e-02,
#        1.44650734e-02, 1.48026913e-02, 1.51481892e-02, 1.55017512e-02,
#        1.58635653e-02, 1.62338243e-02, 1.66127252e-02, 1.70004698e-02,
#        1.73972643e-02, 1.78033202e-02, 1.82188534e-02, 1.86440853e-02,
#        1.90792422e-02, 1.95245558e-02, 1.99802631e-02, 2.04466067e-02,
#        2.09238348e-02, 2.14122015e-02, 2.19119669e-02, 2.24233968e-02,
#        2.29467637e-02, 2.34823460e-02, 2.40304289e-02, 2.45913043e-02,
#        2.51652705e-02, 2.57526333e-02, 2.63537052e-02, 2.69688063e-02,
#        2.75982639e-02, 2.82424133e-02, 2.89015972e-02, 2.95761666e-02,
#        3.02664806e-02, 3.09729067e-02, 3.16958209e-02, 3.24356081e-02,
#        3.31926620e-02, 3.39673858e-02, 3.47601918e-02, 3.55715021e-02,
#        3.64017485e-02, 3.72513730e-02, 3.81208280e-02, 3.90105762e-02,
#        3.99210913e-02, 4.08528580e-02, 4.18063724e-02, 4.27821420e-02,
#        4.37806863e-02, 4.48025368e-02, 4.58482375e-02, 4.69183451e-02,
#        4.80134292e-02, 4.91340729e-02, 5.02808725e-02, 5.14544388e-02,
#        5.26553963e-02, 5.38843844e-02, 5.51420574e-02, 5.64290847e-02,
#        5.77461515e-02, 5.90939590e-02, 6.04732245e-02, 6.18846824e-02,
#        6.33290840e-02, 6.48071983e-02, 6.63198120e-02, 6.78677305e-02,
#        6.94517777e-02, 7.10727970e-02, 7.27316511e-02, 7.44292233e-02,
#        7.61664172e-02, 7.79441575e-02, 7.97633907e-02, 8.16250851e-02,
#        8.35302320e-02, 8.54798453e-02, 8.74749630e-02, 8.95166472e-02,
#        9.16059848e-02, 9.37440879e-02, 9.59320948e-02, 9.81711702e-02,
#        1.00462506e-01, 1.02807322e-01, 1.05206867e-01, 1.07662418e-01,
#        1.10175281e-01, 1.12746796e-01, 1.15378330e-01, 1.18071285e-01,
#        1.20827094e-01, 1.23647224e-01, 1.26533176e-01, 1.29486487e-01,
#        1.32508729e-01, 1.35601511e-01, 1.38766479e-01, 1.42005318e-01,
#        1.45319752e-01, 1.48711546e-01, 1.52182505e-01, 1.55734477e-01,
#        1.59369353e-01, 1.63089068e-01, 1.66895601e-01, 1.70790980e-01,
#        1.74777277e-01, 1.78856616e-01, 1.83031168e-01, 1.87303154e-01,
#        1.91674849e-01, 1.96148581e-01, 2.00726730e-01, 2.05411735e-01,
#        2.10206088e-01, 2.15112343e-01, 2.20133111e-01, 2.25271064e-01,
#        2.30528939e-01, 2.35909533e-01, 2.41415712e-01, 2.47050406e-01,
#        2.52816614e-01, 2.58717408e-01, 2.64755927e-01, 2.70935387e-01,
#        2.77259076e-01, 2.83730362e-01, 2.90352688e-01, 2.97129582e-01,
#        3.04064649e-01, 3.11161583e-01, 3.18424160e-01, 3.25856248e-01,
#        3.33461802e-01, 3.41244871e-01, 3.49209598e-01, 3.57360225e-01,
#        3.65701088e-01, 3.74236629e-01, 3.82971391e-01, 3.91910025e-01,
#        4.01057288e-01, 4.10418050e-01, 4.19997295e-01, 4.29800121e-01,
#        4.39831747e-01, 4.50097513e-01, 4.60602884e-01, 4.71353453e-01,
#        4.82354943e-01, 4.93613210e-01, 5.05134247e-01, 5.16924187e-01,
#        5.28989308e-01, 5.41336030e-01, 5.53970928e-01, 5.66900727e-01,
#        5.80132310e-01, 5.93672722e-01, 6.07529169e-01, 6.21709029e-01,
#        6.36219849e-01, 6.51069356e-01, 6.66265452e-01, 6.81816229e-01,
#        6.97729965e-01, 7.14015130e-01, 7.30680395e-01, 7.47734631e-01,
#        7.65186915e-01, 7.83046540e-01, 8.01323013e-01, 8.20026062e-01,
#        8.39165644e-01, 8.58751948e-01, 8.78795401e-01, 8.99306672e-01,
#        9.20296681e-01, 9.41776601e-01, 9.63757866e-01, 9.86252179e-01,
#        1.00927151e+00, 1.03282813e+00, 1.05693455e+00, 1.08160363e+00,
#        1.10684849e+00, 1.13268257e+00, 1.15911962e+00, 1.18617372e+00,
#        1.21385926e+00, 1.24219100e+00, 1.27118400e+00, 1.30085370e+00,
#        1.33121590e+00, 1.36228676e+00, 1.39408283e+00, 1.42662102e+00,
#        1.45991865e+00, 1.49399346e+00, 1.52886359e+00, 1.56454759e+00,
#        1.60106446e+00, 1.63843365e+00, 1.67667503e+00, 1.71580899e+00,
#        1.75585633e+00, 1.79683839e+00, 1.83877698e+00, 1.88169442e+00,
#        1.92561357e+00, 1.97055780e+00, 2.01655104e+00, 2.06361777e+00,
#        2.11178304e+00, 2.16107251e+00, 2.21151240e+00, 2.26312957e+00,
#        2.31595149e+00, 2.37000629e+00, 2.42532274e+00, 2.48193029e+00,
#        2.53985907e+00, 2.59913992e+00, 2.65980440e+00, 2.72188479e+00,
#        2.78541416e+00, 2.85042632e+00, 2.91695588e+00, 2.98503825e+00,
#        3.05470967e+00, 3.12600724e+00, 3.19896892e+00, 3.27363353e+00,
#        3.35004083e+00, 3.42823149e+00, 3.50824714e+00, 3.59013038e+00,
#        3.67392478e+00, 3.75967497e+00, 3.84742658e+00, 3.93722633e+00,
#        4.02912203e+00, 4.12316259e+00, 4.21939808e+00, 4.31787973e+00,
#        4.41865996e+00, 4.52179242e+00, 4.62733201e+00, 4.73533492e+00,
#        4.84585864e+00, 4.95896201e+00, 5.07470524e+00, 5.19314994e+00,
#        5.31435916e+00, 5.43839743e+00, 5.56533078e+00, 5.69522678e+00,
#        5.82815458e+00, 5.96418495e+00, 6.10339029e+00, 6.24584471e+00,
#        6.39162405e+00, 6.54080591e+00, 6.69346971e+00, 6.84969672e+00,
#        7.00957009e+00, 7.17317494e+00, 7.34059837e+00, 7.51192949e+00,
#        7.68725952e+00, 7.86668179e+00, 8.05029181e+00, 8.23818733e+00,
#        8.43046837e+00, 8.62723729e+00, 8.82859884e+00, 9.03466021e+00,
#        9.24553110e+00, 9.46132376e+00, 9.68215306e+00, 9.90813657e+00,
#        1.01393946e+01, 1.03760502e+01, 1.06182294e+01, 1.08660611e+01,
#        1.11196773e+01, 1.13792129e+01, 1.16448062e+01, 1.19165984e+01,
#        1.21947344e+01, 1.24793621e+01, 1.27706330e+01, 1.30687023e+01,
#        1.33737286e+01, 1.36858742e+01, 1.40053055e+01, 1.43321923e+01,
#        1.46667087e+01, 1.50090328e+01, 1.53593468e+01, 1.57178372e+01,
#        1.60846948e+01, 1.64601150e+01, 1.68442976e+01, 1.72374471e+01,
#        1.76397728e+01, 1.80514888e+01, 1.84728144e+01, 1.89039738e+01,
#        1.93451965e+01, 1.97967175e+01, 2.02587771e+01, 2.07316213e+01,
#        2.12155017e+01, 2.17106760e+01, 2.22174078e+01, 2.27359668e+01,
#        2.32666291e+01, 2.38096772e+01, 2.43654001e+01, 2.49340937e+01,
#        2.55160607e+01, 2.61116110e+01, 2.67210616e+01, 2.73447368e+01,
#        2.79829688e+01, 2.86360972e+01, 2.93044698e+01, 2.99884423e+01,
#        3.06883789e+01, 3.14046522e+01, 3.21376434e+01, 3.28877429e+01,
#        3.36553498e+01, 3.44408728e+01, 3.52447300e+01, 3.60673495e+01,
#        3.69091691e+01, 3.77706369e+01, 3.86522116e+01, 3.95543624e+01,
#        4.04775697e+01, 4.14223247e+01, 4.23891306e+01, 4.33785019e+01,
#        4.43909653e+01, 4.54270599e+01, 4.64873371e+01, 4.75723614e+01,
#        4.86827104e+01, 4.98189752e+01, 5.09817606e+01, 5.21716858e+01,
#        5.33893840e+01, 5.46355035e+01, 5.59107078e+01, 5.72156756e+01,
#        5.85511016e+01, 5.99176967e+01, 6.13161884e+01, 6.27473213e+01,
#        6.42118571e+01, 6.57105755e+01, 6.72442742e+01, 6.88137699e+01,
#        7.04198979e+01, 7.20635132e+01, 7.37454909e+01, 7.54667263e+01,
#        7.72281357e+01, 7.90306568e+01, 8.08752491e+01, 8.27628946e+01,
#        8.46945981e+01, 8.66713880e+01, 8.86943166e+01, 9.07644607e+01,
#        9.28829225e+01, 9.50508296e+01, 9.72693362e+01, 9.95396231e+01,
#        1.01862899e+02, 1.04240401e+02, 1.06673394e+02, 1.09163173e+02,
#        1.11711065e+02, 1.14318425e+02, 1.16986641e+02, 1.19717134e+02,
#        1.22511358e+02, 1.25370799e+02, 1.28296980e+02, 1.31291459e+02,
#        1.34355829e+02, 1.37491723e+02, 1.40700809e+02, 1.43984795e+02,
#        1.47345431e+02, 1.50784505e+02, 1.54303847e+02, 1.57905331e+02,
#        1.61590875e+02, 1.65362441e+02, 1.69222035e+02, 1.73171713e+02,
#        1.77213578e+02, 1.81349780e+02, 1.85582523e+02, 1.89914058e+02,
#        1.94346693e+02, 1.98882786e+02, 2.03524752e+02, 2.08275063e+02,
#        2.13136247e+02, 2.18110892e+02, 2.23201647e+02, 2.28411221e+02,
#        2.33742387e+02, 2.39197984e+02, 2.44780916e+02, 2.50494154e+02,
#        2.56340741e+02, 2.62323788e+02, 2.68446481e+02, 2.74712079e+02,
#        2.81123917e+02, 2.87685409e+02, 2.94400048e+02, 3.01271407e+02,
#        3.08303146e+02, 3.15499006e+02, 3.22862820e+02, 3.30398507e+02,
#        3.38110078e+02, 3.46001639e+02, 3.54077391e+02, 3.62341632e+02,
#        3.70798763e+02, 3.79453285e+02, 3.88309805e+02, 3.97373038e+02,
#        4.06647809e+02, 4.16139055e+02, 4.25851829e+02, 4.35791301e+02,
#        4.45962763e+02, 4.56371628e+02, 4.67023439e+02, 4.77923865e+02,
#        4.89078709e+02, 5.00493910e+02, 5.12175544e+02, 5.24129830e+02,
#        5.36363132e+02, 5.48881961e+02, 5.61692982e+02, 5.74803016e+02,
#        5.88219040e+02, 6.01948197e+02, 6.15997796e+02, 6.30375315e+02,
#        6.45088409e+02, 6.60144909e+02, 6.75552832e+02, 6.91320378e+02,
#        7.07455942e+02, 7.23968114e+02, 7.40865683e+02, 7.58157646e+02,
#        7.75853206e+02, 7.93961785e+02, 8.12493021e+02, 8.31456781e+02,
#        8.50863158e+02, 8.70722485e+02, 8.91045332e+02, 9.11842520e+02,
#        9.33125118e+02, 9.54904456e+02, 9.77192128e+02, 1.00000000e+03])

# %%
#creating CV
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
c_values = np.logspace(-2, 3, 500)
#searching for best hyper-parameters
logit_searcher = LogisticRegressionCV(Cs=c_values, cv=skf, verbose=1, n_jobs=-1)
logit_searcher.fit(X_poly, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.8s finished
# LogisticRegressionCV(Cs=array([1.00000000e-02, 1.02334021e-02, 1.04722519e-02, 1.07166765e-02,
#        1.09668060e-02, 1.12227736e-02, 1.14847155e-02, 1.17527712e-02,
#        1.20270833e-02, 1.23077980e-02, 1.25950646e-02, 1.28890361e-02,
#        1.31898690e-02, 1.34977233e-02, 1.38127630e-02, 1.41351558e-02,
#        1.44650734e-02, 1.48026913e-02, 1.51481892e-02, 1.55017512e-02,
#        1.58635653e-02, 1.62...
#        6.45088409e+02, 6.60144909e+02, 6.75552832e+02, 6.91320378e+02,
#        7.07455942e+02, 7.23968114e+02, 7.40865683e+02, 7.58157646e+02,
#        7.75853206e+02, 7.93961785e+02, 8.12493021e+02, 8.31456781e+02,
#        8.50863158e+02, 8.70722485e+02, 8.91045332e+02, 9.11842520e+02,
#        9.33125118e+02, 9.54904456e+02, 9.77192128e+02, 1.00000000e+03]),
#                      cv=StratifiedKFold(n_splits=5, random_state=17, shuffle=True),
#                      n_jobs=-1, verbose=1)

# %%
print('Best C = ', logit_searcher.C_[0])
# Out:
# Best C =  154.30384691835647

# %% [markdown]
# To see how the quality of the model (percentage of correct responses on the training and validation sets) varies with the hyperparameter $C$, we can plot the graph.

# %%
plt.plot(c_values, np.mean(logit_searcher.scores_[1], axis=0))
# ax.set_yscale('log')
plt.xlabel('C')
plt.ylabel('Mean CV-accuracy');

# %% [markdown]
# # Model for best C

# %%
C = logit_searcher.C_[0]
#C = 10000
logit = LogisticRegression(C=C, random_state=17, penalty = 'l2', max_iter = 1000)
logit.fit(X_poly, y)
print('C = ', C)
print("Accuracy on training set:",  round(logit.score(X_poly, y), 3))

plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title('2 tests of microchips. Logit with C=%s' % C)
plt.legend()
plt.show()
print('\n\n\n')
# Out:
# C =  154.30384691835647
# Accuracy on training set: 0.839

# %% [markdown]
# **Best model coefficients**

# %%
coefs = logit.coef_[0]

plt.figure(figsize=(10, 7))
sns.barplot(y=coefs, x=list(range(len(coefs))))
plt.title('Ridge regression beta coefficients vizualized')
plt.xlabel('Feature index')
plt.ylabel('Coefficient value')
plt.show()

# %% [markdown]
# ### Question Time
#
# How does Lasso differ from Ridge in terms of what it does to coefficients?
# Why might it be especially useful for feature selection?
#
# `Answer is in the hidden cell below`

# %%
# @title
# Ridge shrinks coefficients toward zero but rarely makes them exactly zero
# Lasso can shrink some coefficients to exactly zero so this effectively removes features (kind of auto-feature selection)

# %% [markdown]
# # Lasso regression
#
# Ridge regression does have one obvious disadvantage. It does not do feature selection. Ridge regression will include all $p$ predictors in the final model. The penalty $\lambda |\beta|^2$ will shrink all of the coefficients towards zero, but it will not set any of them exactly to zero. This may not be a problem for prediction accuracy, but it can create a challenge in model interpretation in settings in which the number of variables $p$ is quite large.
#
# The lasso is an alternative to ridge regression that overcomes this disadvantage. The lasso minimizes the following function:
#
#
# $$\Large J(X, y, \beta) = \mathcal{L} + \lambda \sum_j|\beta_j|$$
#
# - $\mathcal{L}$ is the logistic loss function summed over the entire dataset
# - $\lambda \sum_j|\beta_j|$ is called $l_1$ penalty
#
# The lasso and ridge regression have similar formulations. The only difference is that the $\lambda\sum_j\beta_j^2 $ term in the ridge regression penalty has been replaced by $\lambda\sum_j|\beta_j|$ in the lasso penalty.
#
# As with ridge regression, the lasso shrinks the coefficient estimates towards zero. However, in the case of the lasso, the penalty has the effect of forcing some of the coefficient estimates to be exactly equal to zero when
# the tuning parameter $\lambda$ is sufficiently large. Hence, much like best subset selection, the lasso performs *variable selection*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # First experiments with lasso regression
# **Why:** let's repeat the same experiments for lasso regression and build several models with different $C = [0.5, 1,100, 1000, 10000]$.

# %%
LogisticRegression?

# %%
Cs = [0.5, 1,100, 1000, 10000]

for C in Cs:
    logit = LogisticRegression(C=C, penalty = 'l1', random_state=17, solver='liblinear', max_iter = 1000)
    logit.fit(X_poly, y)
    print('C = ', C)
    print("Accuracy on training set:", round(logit.score(X_poly, y), 3))

    plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=poly)

    plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
    plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
    plt.xlabel("Test 1")
    plt.ylabel("Test 2")
    plt.title('2 tests of microchips. Logit with C=%s' % C)
    plt.legend()
    plt.show()
    print('\n\n\n')
# Out:
# C =  0.5
# Accuracy on training set: 0.763
# C =  1
# Accuracy on training set: 0.797
# C =  100
# Accuracy on training set: 0.873
# C =  1000
# Accuracy on training set: 0.873
# C =  10000
# Accuracy on training set: 0.881

# %% [markdown]
# **Takeaway:** once again, the bigger the C is, the less regularized model we get, and the more complex boundary we obtain.

# %% [markdown]
# # GridSearch
#
# **Why:** we will use same strategy (grid search and cross-validation) for finding the best C.

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
c_values = np.logspace(-2, 3, 500)
logit_searcher = LogisticRegressionCV(Cs=c_values, cv=skf, verbose=1, n_jobs=-1, penalty = 'l1',  solver='liblinear')
logit_searcher.fit(X_poly, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   51.3s finished
# LogisticRegressionCV(Cs=array([1.00000000e-02, 1.02334021e-02, 1.04722519e-02, 1.07166765e-02,
#        1.09668060e-02, 1.12227736e-02, 1.14847155e-02, 1.17527712e-02,
#        1.20270833e-02, 1.23077980e-02, 1.25950646e-02, 1.28890361e-02,
#        1.31898690e-02, 1.34977233e-02, 1.38127630e-02, 1.41351558e-02,
#        1.44650734e-02, 1.48026913e-02, 1.51481892e-02, 1.55017512e-02,
#        1.58635653e-02, 1.62...
#        7.07455942e+02, 7.23968114e+02, 7.40865683e+02, 7.58157646e+02,
#        7.75853206e+02, 7.93961785e+02, 8.12493021e+02, 8.31456781e+02,
#        8.50863158e+02, 8.70722485e+02, 8.91045332e+02, 9.11842520e+02,
#        9.33125118e+02, 9.54904456e+02, 9.77192128e+02, 1.00000000e+03]),
#                      cv=StratifiedKFold(n_splits=5, random_state=17, shuffle=True),
#                      n_jobs=-1, penalty='l1', solver='liblinear', verbose=1)

# %%
print('Best C = ', logit_searcher.C_[0])
# Out:
# Best C =  3.428231493733971

# %% [markdown]
# **Takeaway:** in case of the lasso regression C is much lower.
#
# **Learning curve**

# %%
max(np.mean(logit_searcher.scores_[1], axis=0))
# Out:
# np.float64(0.8221014492753623)

# %%
plt.plot(c_values, np.mean(logit_searcher.scores_[1], axis=0))
plt.xlabel('C')
plt.ylabel('Mean CV-accuracy');

# %% [markdown]
# # Best model for lasso regression

# %%
C = logit_searcher.C_[0]
#C = 1000

logit = LogisticRegression(C=C,  penalty = 'l1', random_state=17, solver='liblinear', max_iter = 1000)
logit.fit(X_poly, y)
print('C = ', C)
print("Accuracy on training set:", round(logit.score(X_poly, y), 3))

plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title('2 tests of microchips. Logit with C=%s' % C)
plt.legend()
plt.show()
print('\n\n\n')
# Out:
# C =  3.428231493733971
# Accuracy on training set: 0.856

# %%
coefs = (logit.coef_)[0]

plt.figure(figsize=(10, 7))
sns.barplot(y=coefs, x=list(range(len(coefs))))
plt.title('Lasso regression beta coefficients vizualized')
plt.xlabel('Feature index')
plt.ylabel('Coefficient value')
plt.show()

# %% [markdown]
# **Takeaway** we see that lasso regression shrinked most coefficients practically towards zero.

# %% [markdown]
# # Elastic net
# What if we use both $l_1$ and $l_2$ penalties? What we get is **Elastic Net** regression.

# %%
from sklearn.linear_model import ElasticNetCV, ElasticNet
ElasticNetCV
# Out:
# sklearn.linear_model._coordinate_descent.ElasticNetCV

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)

c_values = np.logspace(0, 1, 100)
l1_coeffs = np.logspace(-3, 4, 300)

# %%
logit_searcher = ElasticNetCV(alphas=c_values, l1_ratio=l1_coeffs, cv=skf, verbose=1, n_jobs=-1, max_iter = 10000)
logit_searcher.fit(X_poly, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ElasticNetCV(alphas=array([ 1.        ,  1.02353102,  1.04761575,  1.07226722,  1.09749877,
#         1.12332403,  1.149757  ,  1.17681195,  1.20450354,  1.23284674,
#         1.26185688,  1.29154967,  1.32194115,  1.35304777,  1.38488637,
#         1.41747416,  1.45082878,  1.48496826,  1.51991108,  1.55567614,
#         1.59228279,  1.62975083,  1.66810054,  1.70735265,  1.7475284 ,
#         1.78864953,  1.83073828,  1.87381742,  1.91791026,  1.96304065,
#         2.00...
#        2.89426612e+03, 3.05456825e+03, 3.22374888e+03, 3.40229977e+03,
#        3.59073989e+03, 3.78961698e+03, 3.99950910e+03, 4.22102632e+03,
#        4.45481252e+03, 4.70154722e+03, 4.96194760e+03, 5.23677054e+03,
#        5.52681486e+03, 5.83292359e+03, 6.15598650e+03, 6.49694260e+03,
#        6.85678294e+03, 7.23655342e+03, 7.63735792e+03, 8.06036141e+03,
#        8.50679342e+03, 8.97795155e+03, 9.47520530e+03, 1.00000000e+04]),
#              max_iter=10000, n_jobs=-1, verbose=1)

# %%
print(f'Best l1 ratio: {logit_searcher.l1_ratio_}, best alpha: {logit_searcher.alpha_}')
# Out:
# Best l1 ratio: 0.001, best alpha: 1.0

# %%
print('Elastic net accuracy on training set', logit_searcher.score(X_poly, y))
# Out:
# Elastic net accuracy on training set 0.07373686861808004

# %%
ElasticNet?

# %%
# C = logit_searcher.C_[0]
#C = 1000

# logit = LogisticRegression(C=C,  penalty = 'elasticnet', random_state=17, solver='liblinear', max_iter = 1000)
logit = ElasticNet(alpha=1, l1_ratio=0.001)
logit.fit(X_poly, y)
# print('C = ', C)
print("Accuracy on training set:", round(logit.score(X_poly, y), 3))

plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
plt.xlabel("Test 1")
plt.ylabel("Test 2")
# plt.title('2 tests of microchips. Logit with C=%s' % C)
plt.legend()
plt.show()
print('\n\n\n')
# Out:
# Accuracy on training set: 0.074

# %% [markdown]
# # 🚨 Mistake: Regression Instead of Classification
#
# In the previous code we used **`ElasticNet`** / **`ElasticNetCV`**, which are **regression** models.
# That was incorrect because:
#
# - Our target variable is **binary** (classification, not regression).
# - `.score()` in regression is **R²**, not **accuracy**.
# - The decision boundary from regression is meaningless for classification.
# - Always check the documentation!
#
# 👉 For **classification with elastic-net penalty**, we must use
# `LogisticRegression` / `LogisticRegressionCV` with:
# - `penalty='elasticnet'`
# - `solver='saga'`
# - hyperparameters: **`C`** (inverse of regularization strength) and **`l1_ratio`**.

# %% [markdown]
# # ✅ Correct Approach: Elastic Net for Classification
#
# Now we’ll properly apply **Elastic Net** regularization in logistic regression.
# We’ll use cross-validation to find the best values of `C` and `l1_ratio`.

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import accuracy_score, roc_auc_score

# --- data split (optional but recommended for teaching) ---
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=17, test_size=0.25)

# --- feature map (your poly featurizer) ---
poly = PolynomialFeatures(degree=5, include_bias=False)

# --- CV setup ---
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)

# --- hyperparameters ---
Cs = np.logspace(-3, 3, 20)           # inverse regularization strengths
l1_ratios = np.linspace(0.0, 1.0, 11) # 0=L2, 1=L1, in-between=elastic net

# --- pipeline: scale -> poly -> logistic with elastic-net ---
clf_cv = Pipeline([
    ("poly", poly),
    ("scaler", StandardScaler(with_mean=False)),  # with_mean=False pairs nicely with sparse poly features
    ("logit_cv", LogisticRegressionCV(
        Cs=Cs,
        l1_ratios=l1_ratios,
        cv=skf,
        penalty="elasticnet",
        solver="saga",
        scoring="accuracy",
        max_iter=5000,
        n_jobs=-1,
        refit=True
    ))
])

clf_cv.fit(X_train, y_train)

best_C = clf_cv.named_steps["logit_cv"].C_[0]
best_l1 = clf_cv.named_steps["logit_cv"].l1_ratio_[0]

print(f"Best hyperparameters → C={best_C:.5g}, l1_ratio={best_l1:.3f}")

# Train/test metrics
y_tr_pred = clf_cv.predict(X_train)
y_te_pred = clf_cv.predict(X_test)

print("Accuracy (train):", round(accuracy_score(y_train, y_tr_pred), 3))
print("Accuracy (test): ", round(accuracy_score(y_test,  y_te_pred), 3))

# Optional: ROC AUC (needs predict_proba or decision_function)
y_te_proba = clf_cv.predict_proba(X_test)[:, 1]
print("ROC AUC (test):  ", round(roc_auc_score(y_test, y_te_proba), 3))
# Out:
# Best hyperparameters → C=0.69519, l1_ratio=0.600
# Accuracy (train): 0.852
# Accuracy (test):  0.767
# ROC AUC (test):   0.867

# %% [markdown]
# # 🎯 Final Model for Visualization
#
# Now let’s refit a plain Logistic Regression model with the **best parameters**
# and visualize the decision boundary.

# %%
# Refit a plain LogisticRegression with the CV-chosen params (clear for students)
logit = Pipeline([
    ("poly", poly),
    ("scaler", StandardScaler(with_mean=False)),
    ("clf", LogisticRegression(
        C=best_C,
        l1_ratio=best_l1,
        penalty="elasticnet",
        solver="saga",
        max_iter=5000,
        random_state=17
    ))
]).fit(X, y)

print("Accuracy on full data:", round(logit.score(X, y), 3))

# Your decision boundary utility likely calls .predict on the final estimator in the pipeline.
plot_boundary(logit, X, y, grid_step=.01, poly_featurizer=None)  # poly is inside the pipeline now

plt.scatter(X[y == 1, 0], X[y == 1, 1], c='blue', label='Released')
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='orange', label='Faulty')
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.legend()
plt.show()
# Out:
# Accuracy on full data: 0.822

# %%
clf   = logit.named_steps["clf"]
coefs = clf.coef_.ravel()
plt.figure(figsize=(12,6))
sns.barplot(x=np.arange(coefs.size), y=coefs)
plt.axhline(0, color="k", lw=1)
plt.title("Elastic-Net Logistic coefficients (all features)")
plt.xlabel("Feature index")
plt.ylabel("Coefficient")
plt.tight_layout()
plt.show()

# %% [markdown]
# # ⚠️ Recap
# - ❌ Used `ElasticNet` / `ElasticNetCV` (regression) instead of classification.
# - ❌ Interpreted regression `.score` (R²) as accuracy.
# - ❌ Tried to tune `alpha` instead of `C`.
# - ❌ Used `liblinear` solver (does not support `penalty='elasticnet'`).
# - ⚠️ No scaling for polynomial features.
#
# ✅ Correct fix: `LogisticRegression` / `LogisticRegressionCV` with
# `penalty='elasticnet'`, `solver='saga'`, tuned over `C` + `l1_ratio`.

# %% [markdown]
# # Exercise
# Lasso regression could be used for feature selection. If the coefficient becomes small, we could drop it from the feature subset and build model only on features that correspond to large coefficients.
#
# 1. Fit a lasso regression and obtain coefficients with absolute values greater than 0.001
# 2. Fit a ridge regression using the selected features only
# 3. Fit a lasso regression using the selected features only
# 4. Compare the results to previous findings: does using feature selection produce a better accuracy?
